# %%
# %pip install -q llama-index
# %pip install -q llama-index-llms-groq
# %pip install -q llama-index-embeddings-huggingface
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 32.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 47.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.0/189.0 kB 11.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 15.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 28.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 2.5 MB/s eta 0:00:00

# %%
# NOTE: This is ONLY necessary in jupyter notebook.
# Details: Jupyter runs an event-loop behind the scenes.
#          This results in nested event-loops when we start an event-loop to make async queries.
#          This is normally not allowed, we use nest_asyncio to allow it for convenience.
import nest_asyncio

nest_asyncio.apply()

import logging
import sys

# Set up the root logger
logger = logging.getLogger()
logger.setLevel(logging.INFO)  # Set logger level to INFO

# Clear out any existing handlers
logger.handlers = []

# Set up the StreamHandler to output to sys.stdout (Colab's output)
handler = logging.StreamHandler(sys.stdout)
handler.setLevel(logging.INFO)  # Set handler level to INFO

# Add the handler to the logger
logger.addHandler(handler)

from IPython.display import display, HTML

# %%
from llama_index.core import (
    VectorStoreIndex,
    SimpleDirectoryReader,
    StorageContext,
    load_index_from_storage
)
from llama_index.core.settings import Settings
from llama_index.llms.groq import Groq
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
# Out:
# NumExpr defaulting to 2 threads.

# %%
from google.colab import userdata

llm = Groq(model="llama3-groq-70b-8192-tool-use-preview", api_key=userdata.get('GROQ_API_KEY'))
embed_model = HuggingFaceEmbedding(model_name="BAAI/bge-small-en-v1.5")
# Out:
# Load pretrained SentenceTransformer: BAAI/bge-small-en-v1.5
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/94.8k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# 2 prompts are loaded, with the keys: ['query', 'text']

# %%
from llama_index.core import Settings
Settings.llm = llm
Settings.embed_model = embed_model
Settings.chunk_size = 512

# %%
wiki_titles = ["Toronto", "Seattle", "Chicago", "Boston", "Houston"]

from pathlib import Path

import requests

for title in wiki_titles:
    response = requests.get(
        "https://en.wikipedia.org/w/api.php",
        params={
            "action": "query",
            "format": "json",
            "titles": title,
            "prop": "extracts",
            # 'exintro': True,
            "explaintext": True,
        },
    ).json()
    page = next(iter(response["query"]["pages"].values()))
    wiki_text = page["extract"]

    data_path = Path("data")
    if not data_path.exists():
        Path.mkdir(data_path)

    with open(data_path / f"{title}.txt", "w") as fp:
        fp.write(wiki_text)

# %%
# Load all wiki documents

from llama_index.core import SimpleDirectoryReader

city_docs = {}
for wiki_title in wiki_titles:
    city_docs[wiki_title] = SimpleDirectoryReader(
        input_files=[f"data/{wiki_title}.txt"]
    ).load_data()

# %%
from llama_index.core.agent import ReActAgent
from llama_index.core import VectorStoreIndex, SummaryIndex
from llama_index.core.tools import QueryEngineTool, ToolMetadata

# Build agents dictionary
agents = {}

for wiki_title in wiki_titles:
    # build vector index
    vector_index = VectorStoreIndex.from_documents(
        city_docs[wiki_title],
    )
    # build summary index
    summary_index = SummaryIndex.from_documents(
        city_docs[wiki_title],
    )
    # define query engines
    vector_query_engine = vector_index.as_query_engine()
    summary_query_engine = summary_index.as_query_engine()

    # define tools
    query_engine_tools = [
        QueryEngineTool(
            query_engine=vector_query_engine,
            metadata=ToolMetadata(
                name="vector_tool",
                description=(
                    f"Useful for retrieving specific context from {wiki_title}"
                ),
            ),
        ),
        QueryEngineTool(
            query_engine=summary_query_engine,
            metadata=ToolMetadata(
                name="summary_tool",
                description=(
                    "Useful for summarization questions related to"
                    f" {wiki_title}"
                ),
            ),
        ),
    ]

    # build agent
    agent = ReActAgent.from_tools(
        query_engine_tools,
        llm=llm,
        verbose=True,
    )

    agents[wiki_title] = agent
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
from llama_index.core.schema import IndexNode

# define top-level nodes
objects = []
for wiki_title in wiki_titles:
    # define index node that links to these agents
    wiki_summary = (
        f"This content contains Wikipedia articles about {wiki_title}. Use"
        " this index if you need to lookup specific facts about"
        f" {wiki_title}.\nDo not use this index if you want to analyze"
        " multiple cities."
    )
    node = IndexNode(
        text=wiki_summary, index_id=wiki_title, obj=agents[wiki_title]
    )
    objects.append(node)

# %%
vector_index = VectorStoreIndex(
    objects=objects,
)
query_engine = vector_index.as_query_engine(similarity_top_k=1, verbose=True)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# Helper function for print
def print_response(response):
    display(HTML(f'<p style="font-size:20px">{response.response}</p>'))

# %%
# should use Toronto agent -> vector tool
response = query_engine.query("What is the population of Toronto?")
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieval entering Toronto: ReActAgent
# Retrieving from object ReActAgent with query What is the population of Toronto?
# > Running step d183b183-fe6c-43f4-86b2-79140627a695. Step input: What is the population of Toronto?
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Thought: The current language of the user is: English. I need to use a tool to help me answer the question.
# Action: vector_tool
# Action Input: {'input': 'What is the population of Toronto?'}
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Observation: The population of Toronto is 2,794,356 in 2021.
# > Running step 9ed58a08-d738-4217-b055-805b34a9d1ab. Step input: None
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Thought: (Implicit) I can answer without any more tools!
# Answer: Answer: The population of Toronto is 2,794,356 in 2021.
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"

# %%
print_response(response)
# Out:
# <p style="font-size:20px">The population of Toronto is 2,794,356 in 2021.</p>

# %%
# should use Houston agent -> vector tool
response = query_engine.query("Who and when was Houston founded?")
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieval entering Houston: ReActAgent
# Retrieving from object ReActAgent with query Who and when was Houston founded?
# > Running step d09b9f49-7615-4c35-a073-139e54d949d5. Step input: Who and when was Houston founded?
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Thought: The current language of the user is: English. I need to use a tool to help me answer the question.
# Action: vector_tool
# Action Input: {'input': 'Who founded Houston?'}
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Observation: The Allen brothers founded Houston.
# > Running step efddc8a7-fa92-4ddd-a956-7e75f84d9af8. Step input: None
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Thought: The current language of the user is: English. I need to use a tool to help me answer the question.
# Action: vector_tool
# Action Input: {'input': 'When was Houston founded?'}
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Observation: Houston was founded in 1836.
# > Running step 0225ac4a-b786-43c2-a770-c0e244790572. Step input: None
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Thought: I can answer without using any more tools. I'll use the user's language to answer
# Answer: Houston was founded by the Allen brothers in 1836.
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"

# %%
print_response(response)
# Out:
# <p style="font-size:20px">Houston was founded by the Allen brothers in 1836.</p>

# %%
# should use Boston agent -> summary tool
response = query_engine.query("Summarize about the sports teams in Boston")
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieval entering Boston: ReActAgent
# Retrieving from object ReActAgent with query Summarize about the sports teams in Boston
# > Running step 194427e1-219b-4709-9a56-dcc5faf8d07b. Step input: Summarize about the sports teams in Boston
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Thought: The current language of the user is: English. I need to use a tool to help me answer the question.
# Action: summary_tool
# Action Input: {'input': 'sports teams in Boston'}
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 14.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 16.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 18.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 14.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 14.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 1.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 3.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Observation: The context information does not provide specific details about sports teams in Boston. However, it does mention Fenway Park, which is home to the Boston Red Sox, and the Boston Garden, which opened in 1928.
# > Running step 007268a3-eb34-4ebe-919f-7d11e3253f04. Step input: None
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 2.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Thought: I need to use a tool to get more specific information about sports teams in Boston.
# Action: vector_tool
# Action Input: {'input': 'sports teams in Boston'}
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 5.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Observation: The sports teams in Boston include the Boston Red Sox (MLB), Boston Bruins (NHL), Boston Celtics (NBA), New England Patriots (NFL), and New England Revolution (MLS).
# > Running step f2add356-b394-48df-9a3d-32ccef45e3a0. Step input: None
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 2.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Thought: I can answer without using any more tools. I'll use the user's language to answer
# Answer: The sports teams in Boston include the Boston Red Sox (MLB), Boston Bruins (NHL), Boston Celtics (NBA), New England Patriots (NFL), and New England Revolution (MLS).
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"

# %%
print_response(response)
# Out:
# <p style="font-size:20px">The sports teams in Boston include the Boston Red Sox (MLB), Boston Bruins (NHL), Boston Celtics (NBA), New England Patriots (NFL), and New England Revolution (MLS).</p>

# %%
# should use Seattle agent -> summary tool
response = query_engine.query(
    "Give me a summary on all the positive aspects of Chicago"
)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieval entering Chicago: ReActAgent
# Retrieving from object ReActAgent with query Give me a summary on all the positive aspects of Chicago
# > Running step 89a57c34-dcda-4b6e-8296-5435226e2be6. Step input: Give me a summary on all the positive aspects of Chicago
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Thought: The current language of the user is: English. I need to use a tool to help me answer the question.
# Action: summary_tool
# Action Input: {'input': 'Give me a summary on all the positive aspects of Chicago'}
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 13.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 17.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 1.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 15.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 2.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 17.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 1.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 16.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 1.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 17.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 1.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 16.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 2.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 9.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Observation: Chicago, the third-most populous city in the United States, has a rich history dating back to the 18th century. The city has been a hub for transportation, industry, and innovation, with significant contributions to public health, social reform, and cultural development. Chicago hosted the influential World's Columbian Exposition in 1893, which drew 27.5 million visitors and showcased the city's architectural prowess. The city's park system, established in 1866, has been a model for other cities. Chicago has also been a center for education, with the University of Chicago moving to its current location in 1892. The city has a strong tradition of social reform, with Jane Addams and Ellen Gates Starr founding Hull House in 1889, which became a model for social work. Chicago has also been a hub for cultural development, with the Chicago Black Renaissance in the 1920s and 1930s, which had a significant impact on art, literature, and music. The city has also been home to influential figures such as Abraham Lincoln, who was nominated for U.S. president in Chicago in 1860.
# > Running step 0d7740b9-2d75-4116-8a6f-d2b9467e5c2e. Step input: None
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 2.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Thought: I can answer without using any more tools. I'll use the user's language to answer
# Answer: Chicago, the third-most populous city in the United States, has a rich history dating back to the 18th century. The city has been a hub for transportation, industry, and innovation, with significant contributions to public health, social reform, and cultural development. Chicago hosted the influential World's Columbian Exposition in 1893, which drew 27.5 million visitors and showcased the city's architectural prowess. The city's park system, established in 1866, has been a model for other cities. Chicago has also been a center for education, with the University of Chicago moving to its current location in 1892. The city has a strong tradition of social reform, with Jane Addams and Ellen Gates Starr founding Hull House in 1889, which became a model for social work. Chicago has also been a hub for cultural development, with the Chicago Black Renaissance in the 1920s and 1930s, which had a significant impact on art, literature, and music. The city has also been home to influential figures such as Abraham Lincoln, who was nominated for U.S. president in Chicago in 1860.
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 1.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"

# %%
print_response(response)
# Out:
# <p style="font-size:20px">Chicago is a city with a rich history, dating back to the 18th century. It has been a hub for transportation, industry, and innovation, making significant contributions to public health, social reform, and cultural development. The city hosted the influential World's Columbian Exposition in 1893, which showcased its architectural prowess and drew 27.5 million visitors. Chicago's park system, established in 1866, has been a model for other cities. The city has a strong tradition of education, with the University of Chicago moving to its current location in 1892. Chicago has also been a center for social reform, with the founding of Hull House in 1889, which became a model for social work. The city has a rich cultural heritage, with the Chicago Black Renaissance in the 1920s and 1930s, which had a significant impact on art, literature, and music. Chicago has also been home to influential figures such as Abraham Lincoln, who was nominated for U.S. president in Chicago in 1860.</p>

# %%
response = query_engine.query(
    "Tell me about the similarity of life in Chicago and Totonto."
)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieval entering Chicago: ReActAgent
# Retrieving from object ReActAgent with query Tell me about the similarity of life in Chicago and Totonto.
# > Running step 1bcd3246-9a45-4a6c-874a-1dfed6e6fc65. Step input: Tell me about the similarity of life in Chicago and Totonto.
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Thought: The current language of the user is: English. I need to use a tool to help me answer the question.
# Action: vector_tool
# Action Input: {'input': 'Chicago'}
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Observation: Chicago is the most populous city in the U.S. state of Illinois and in the Midwestern United States. It is the third-most populous city in the United States after New York City and Los Angeles. Chicago is located in northeastern Illinois on the southwestern shores of freshwater Lake Michigan. The city rests on a continental divide at the site of the Chicago Portage, connecting the Mississippi River and the Great Lakes watersheds. Chicago's history and economy are closely tied to its proximity to Lake Michigan. The city is known for its contributions to urban planning and architecture, such as the Chicago School, the development of the City Beautiful movement, and the steel-framed skyscraper. Chicago is an international hub for finance, culture, commerce, industry, education, technology, telecommunications, and transportation. It has the largest and most diverse finance derivatives market in the world, generating 20% of all volume in commodities and financial futures alone. O'Hare International Airport is one of the world's top six busiest airports by passenger traffic, and the region is also the nation's railroad hub. The Chicago area has one of the highest gross domestic products (GDP) of any urban region in the world, generating $689 billion in 2018. Chicago's economy is diverse, with no single industry employing more than 14% of the workforce. Chicago is a major destination for tourism, including visitors to its cultural institutions, and Lake Michigan beaches. Chicago's culture has contributed much to the visual arts, literature, film, theater, comedy (especially improvisational comedy), food, dance, and music (particularly jazz, blues, soul, hip-hop, gospel, and electronic dance music, including house music). Chicago is home to the Chicago Symphony Orchestra and the Lyric Opera of Chicago, while the Art Institute of Chicago provides an influential visual arts museum and art school. The Chicago area also hosts the University of Chicago, Northwestern University, and the University of Illinois Chicago, among other institutions of learning. Professional sports in Chicago include all major professional leagues, including two Major League Baseball teams.
# > Running step fffaec60-d6ed-4dea-b545-cd0cb581d02a. Step input: None
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Thought: The current language of the user is: English. I need to use a tool to help me answer the question.
# Action: vector_tool
# Action Input: {'input': 'Toronto'}
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Observation: The context information provided does not mention Toronto.
# > Running step 11f4c79b-d570-43e5-8c16-31de8e0ab7d1. Step input: None
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Thought: The current language of the user is: English. I need to use a tool to help me answer the question.
# Action: summary_tool
# Action Input: {'input': 'Chicago and Toronto comparison'}
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 1.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 15.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 3.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 17.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 2.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 16.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 2.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 17.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 2.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 15.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 3.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 9.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Observation: Chicago and Toronto are two prominent cities in North America, with Chicago located in the United States and Toronto in Canada. Both cities boast a rich history and have experienced substantial growth and development over the years. They share similarities in their economic, cultural, and social aspects, but also have distinct differences.
#
# Both Chicago and Toronto are renowned for their vibrant cultural scenes, featuring numerous museums, galleries, and performance venues. They are also major hubs for finance, commerce, and industry, with Chicago being a center for railroads and Toronto being a key location for finance and business. Both cities have a strong sense of community, with diverse neighborhoods and a thriving arts scene.
#
# However, there are also differences between the two cities. Chicago is known for its deep-dish pizza, while Toronto is famous for its multicultural cuisine. Chicago has a more prominent role in the history of jazz and blues music, while Toronto has a strong presence in the music industry, particularly in rock and pop music. Chicago has a more extensive public transportation system, including a comprehensive network of buses and trains, while Toronto has a more limited public transit system, although it is expanding.
#
# In terms of population, Chicago has a larger population than Toronto, with approximately 2.7 million residents compared to Toronto's 2.6 million. However, Toronto has a larger metropolitan area population, with over 6.4 million people compared to Chicago's 9.5 million.
#
# Overall, while both Chicago and Toronto are significant cities in North America, they have distinct histories, cultures, and economies.
# > Running step 144e536e-7172-450f-8e39-802ffb926978. Step input: None
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 5.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Thought: The current language of the user is: English. I need to use a tool to help me answer the question.
# Action: summary_tool
# Action Input: {'input': 'Chicago and Toronto comparison'}
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 15.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 1.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 17.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 2.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 16.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 3.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 17.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 2.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 16.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 2.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 17.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 3.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 15.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 3.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 10.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Observation: Chicago and Toronto are two prominent cities in North America, with Chicago located in the United States and Toronto in Canada. Both cities have a rich history and have experienced significant growth and development over the years.
#
# Chicago, as mentioned in the context, was a major transportation hub in the 1800s, with railroads and the Illinois and Michigan Canal connecting the city to the rest of the country. It was also a center for industry, attracting African Americans from the Southern United States during the Great Migration. The city has a history of labor conflicts, gangster era, and public health improvements, including the establishment of the Chicago Board of Health and the creation of the Illinois State Board of Health.
#
# Toronto, on the other hand, has a history dating back to the 18th century when it was a British colonial town. It has grown to become the largest city in Canada and a major financial and cultural center. Toronto has a diverse economy, with strong industries in finance, technology, media, and arts. The city has a rich cultural scene, with numerous museums, galleries, and festivals celebrating its diverse communities.
#
# In terms of population, Chicago has a population of approximately 2.7 million, while Toronto has a population of about 2.7 million. Both cities are known for their vibrant cultural scenes, with numerous museums, galleries, and festivals celebrating their diverse communities. They also share a strong sense of community and a commitment to improving public health and sanitation.
#
# However, the two cities have different histories and cultural influences. Chicago has a strong connection to the American Civil War and the Prohibition era, while Toronto has a history rooted in British colonialism and Canadian identity. Chicago is known for its role in the labor movement and the development of the steel-skeleton construction, while Toronto is recognized for its diverse economy and cultural institutions.
# > Running step 92f0d7eb-f5ea-455f-a625-d6ba02c52b58. Step input: None
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 7.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Thought: The current language of the user is: English. I need to use a tool to help me answer the question.
# Action: summary_tool
# Action Input: {'input': 'Chicago and Toronto comparison'}
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 14.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 17.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 16.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 1.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 17.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 1.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 16.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 17.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 1.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 15.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 2.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# Retrying request to /chat/completions in 8.000000 seconds
# HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Observation: Chicago and Toronto are two prominent cities in North America, with Chicago situated in the United States and Toronto in Canada. Both cities have a rich history and have experienced significant growth and development over the years. Chicago is known for its role in the American Civil War, its influence on public health reform, and its notorious gangster era during the Prohibition period, which saw infamous figures like Al Capone, Dion O'Banion, Bugs Moran, and Tony Accardo battle law enforcement and each other on the streets of Chicago. The city was also the location of the infamous St. Valentine's Day Massacre in 1929. Toronto, on the other hand, has a history dating back to the French colonial era and has evolved into a multicultural city with a strong economy and diverse culture. Both cities have played important roles in their respective countries' histories and continue to be significant urban centers today.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-8ca6cfd5169d> in <cell line: 1>()
# ----> 1 response = query_engine.query(
#       2     "Tell me about the similarity of life in Chicago and Totonto."
#       3 )
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in wrapper(func, instance, args, kwargs)
#     309
#     310             try:
# --> 311                 result = func(*args, **kwargs)
#     312                 if isinstance(result, asyncio.Future):
#     313                     # If the result is a Future, wrap it
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/base/base_query_engine.py in query(self, str_or_query_bundle)
#      50             if isinstance(str_or_query_bundle, str):
#      51                 str_or_query_bundle = QueryBundle(str_or_query_bundle)
# ---> 52             query_result = self._query(str_or_query_bundle)
#      53         dispatcher.event(
#      54             QueryEndEvent(query=str_or_query_bundle, response=query_result)
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in wrapper(func, instance, args, kwargs)
#     309
#     310             try:
# --> 311                 result = func(*args, **kwargs)
#     312                 if isinstance(result, asyncio.Future):
#     313                     # If the result is a Future, wrap it
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/query_engine/retriever_query_engine.py in _query(self, query_bundle)
#     176             CBEventType.QUERY, payload={EventPayload.QUERY_STR: query_bundle.query_str}
#     177         ) as query_event:
# --> 178             nodes = self.retrieve(query_bundle)
#     179             response = self._response_synthesizer.synthesize(
#     180                 query=query_bundle,
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/query_engine/retriever_query_engine.py in retrieve(self, query_bundle)
#     131
#     132     def retrieve(self, query_bundle: QueryBundle) -> List[NodeWithScore]:
# --> 133         nodes = self._retriever.retrieve(query_bundle)
#     134         return self._apply_node_postprocessors(nodes, query_bundle=query_bundle)
#     135
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in wrapper(func, instance, args, kwargs)
#     309
#     310             try:
# --> 311                 result = func(*args, **kwargs)
#     312                 if isinstance(result, asyncio.Future):
#     313                     # If the result is a Future, wrap it
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/base/base_retriever.py in retrieve(self, str_or_query_bundle)
#     244             ) as retrieve_event:
#     245                 nodes = self._retrieve(query_bundle)
# --> 246                 nodes = self._handle_recursive_retrieval(query_bundle, nodes)
#     247                 retrieve_event.on_end(
#     248                     payload={EventPayload.NODES: nodes},
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/base/base_retriever.py in _handle_recursive_retrieval(self, query_bundle, nodes)
#     166                         )
#     167                     retrieved_nodes.extend(
# --> 168                         self._retrieve_from_object(
#     169                             obj, query_bundle=query_bundle, score=score
#     170                         )
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/base/base_retriever.py in _retrieve_from_object(self, obj, query_bundle, score)
#      91             return [NodeWithScore(node=obj, score=score)]
#      92         elif isinstance(obj, BaseQueryEngine):
# ---> 93             response = obj.query(query_bundle)
#      94             return [
#      95                 NodeWithScore(
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in wrapper(func, instance, args, kwargs)
#     309
#     310             try:
# --> 311                 result = func(*args, **kwargs)
#     312                 if isinstance(result, asyncio.Future):
#     313                     # If the result is a Future, wrap it
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/base/base_query_engine.py in query(self, str_or_query_bundle)
#      50             if isinstance(str_or_query_bundle, str):
#      51                 str_or_query_bundle = QueryBundle(str_or_query_bundle)
# ---> 52             query_result = self._query(str_or_query_bundle)
#      53         dispatcher.event(
#      54             QueryEndEvent(query=str_or_query_bundle, response=query_result)
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in wrapper(func, instance, args, kwargs)
#     309
#     310             try:
# --> 311                 result = func(*args, **kwargs)
#     312                 if isinstance(result, asyncio.Future):
#     313                     # If the result is a Future, wrap it
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/callbacks/utils.py in wrapper(self, *args, **kwargs)
#      39             callback_manager = cast(CallbackManager, callback_manager)
#      40             with callback_manager.as_trace(trace_id):
# ---> 41                 return func(self, *args, **kwargs)
#      42
#      43         @functools.wraps(func)  # preserve signature, name, etc. of func
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/base/agent/types.py in _query(self, query_bundle)
#      47     @trace_method("query")
#      48     def _query(self, query_bundle: QueryBundle) -> RESPONSE_TYPE:
# ---> 49         agent_response = self.chat(
#      50             query_bundle.query_str,
#      51             chat_history=[],
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in wrapper(func, instance, args, kwargs)
#     309
#     310             try:
# --> 311                 result = func(*args, **kwargs)
#     312                 if isinstance(result, asyncio.Future):
#     313                     # If the result is a Future, wrap it
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/callbacks/utils.py in wrapper(self, *args, **kwargs)
#      39             callback_manager = cast(CallbackManager, callback_manager)
#      40             with callback_manager.as_trace(trace_id):
# ---> 41                 return func(self, *args, **kwargs)
#      42
#      43         @functools.wraps(func)  # preserve signature, name, etc. of func
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/agent/runner/base.py in chat(self, message, chat_history, tool_choice)
#     645             payload={EventPayload.MESSAGES: [message]},
#     646         ) as e:
# --> 647             chat_response = self._chat(
#     648                 message=message,
#     649                 chat_history=chat_history,
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in wrapper(func, instance, args, kwargs)
#     309
#     310             try:
# --> 311                 result = func(*args, **kwargs)
#     312                 if isinstance(result, asyncio.Future):
#     313                     # If the result is a Future, wrap it
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/agent/runner/base.py in _chat(self, message, chat_history, tool_choice, mode)
#     577         while True:
#     578             # pass step queue in as argument, assume step executor is stateless
# --> 579             cur_step_output = self._run_step(
#     580                 task.task_id, mode=mode, tool_choice=tool_choice
#     581             )
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in wrapper(func, instance, args, kwargs)
#     309
#     310             try:
# --> 311                 result = func(*args, **kwargs)
#     312                 if isinstance(result, asyncio.Future):
#     313                     # If the result is a Future, wrap it
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/agent/runner/base.py in _run_step(self, task_id, step, input, mode, **kwargs)
#     410
#     411         if mode == ChatResponseMode.WAIT:
# --> 412             cur_step_output = self.agent_worker.run_step(step, task, **kwargs)
#     413         elif mode == ChatResponseMode.STREAM:
#     414             cur_step_output = self.agent_worker.stream_step(step, task, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in wrapper(func, instance, args, kwargs)
#     309
#     310             try:
# --> 311                 result = func(*args, **kwargs)
#     312                 if isinstance(result, asyncio.Future):
#     313                     # If the result is a Future, wrap it
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/callbacks/utils.py in wrapper(self, *args, **kwargs)
#      39             callback_manager = cast(CallbackManager, callback_manager)
#      40             with callback_manager.as_trace(trace_id):
# ---> 41                 return func(self, *args, **kwargs)
#      42
#      43         @functools.wraps(func)  # preserve signature, name, etc. of func
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/agent/react/step.py in run_step(self, step, task, **kwargs)
#     816     def run_step(self, step: TaskStep, task: Task, **kwargs: Any) -> TaskStepOutput:
#     817         """Run step."""
# --> 818         return self._run_step(step, task)
#     819
#     820     @trace_method("run_step")
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/agent/react/step.py in _run_step(self, step, task)
#     574         )
#     575         task.extra_state["current_reasoning"].extend(reasoning_steps)
# --> 576         agent_response = self._get_response(
#     577             task.extra_state["current_reasoning"], task.extra_state["sources"]
#     578         )
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/agent/react/step.py in _get_response(self, current_reasoning, sources)
#     435             raise ValueError("No reasoning steps were taken.")
#     436         elif len(current_reasoning) == self._max_iterations:
# --> 437             raise ValueError("Reached max iterations.")
#     438
#     439         if isinstance(current_reasoning[-1], ResponseReasoningStep):
#
# ValueError: Reached max iterations.

# %%
print_response(response)
# Out:
# <p style="font-size:20px">Chicago is a city with a rich history, dating back to the 18th century. It has been a hub for transportation, industry, and innovation, making significant contributions to public health, social reform, and cultural development. The city hosted the influential World's Columbian Exposition in 1893, which showcased its architectural prowess and drew 27.5 million visitors. Chicago's park system, established in 1866, has been a model for other cities. The city has a strong tradition of education, with the University of Chicago moving to its current location in 1892. Chicago has also been a center for social reform, with the founding of Hull House in 1889, which became a model for social work. The city has a rich cultural heritage, with the Chicago Black Renaissance in the 1920s and 1930s, which had a significant impact on art, literature, and music. Chicago has also been home to influential figures such as Abraham Lincoln, who was nominated for U.S. president in Chicago in 1860.</p>

# %%
#assignment (wayback may 13)
"Tell me how many shows has Shen Yun performed in 2023."

# %%
#Import and load new wiki documents
wiki_titles = ["Shen Yun"]
for title in wiki_titles:
    response = requests.get(
        "https://en.wikipedia.org/w/api.php",
        params={
            "action": "query",
            "format": "json",
            "titles": title,
            "prop": "extracts",
            # 'exintro': True,
            "explaintext": True,
        },
    ).json()
    page = next(iter(response["query"]["pages"].values()))
    wiki_text = page["extract"]

    data_path = Path("data")
    if not data_path.exists():
        Path.mkdir(data_path)

    with open(data_path / f"{title}.txt", "w") as fp:
        fp.write(wiki_text)

city_docs = {}
for wiki_title in wiki_titles:
    city_docs[wiki_title] = SimpleDirectoryReader(
        input_files=[f"data/{wiki_title}.txt"]
    ).load_data()
